# %%
import torch
import pickle

# %%
indices
# Out:
# {'FADG0': 0,
#  'FAEM0': 1,
#  'FAJW0': 2,
#  'FAKS0': 3,
#  'FALK0': 4,
#  'FALR0': 5,
#  'FAPB0': 6,
#  'FASW0': 7,
#  'FAWF0': 8,
#  'FBAS0': 9,
#  'FBCG1': 10,
#  'FBCH0': 11,
#  'FBJL0': 12,
#  'FBLV0': 13,
#  'FBMH0': 14,
#  'FBMJ0': 15,
#  'FCAG0': 16,
#  'FCAJ0': 17,
#  'FCAL1': 18,
#  'FCAU0': 19,
#  'FCDR1': 20,
#  'FCEG0': 21,
#  'FCFT0': 22,
#  'FCJF0': 23,
#  'FCJS0': 24,
#  'FCKE0': 25,
#  'FCLT0': 26,
#  'FCMG0': 27,
#  'FCMH0': 28,
#  'FCMH1': 29,
#  'FCMM0': 30,
#  'FCMR0': 31,
#  'FCRH0': 32,
#  'FCRZ0': 33,
#  'FCYL0': 34,
#  'FDAC1': 35,
#  'FDAS1': 36,
#  'FDAW0': 37,
#  'FDFB0': 38,
#  'FDHC0': 39,
#  'FDJH0': 40,
#  'FDKN0': 41,
#  'FDML0': 42,
#  'FDMS0': 43,
#  'FDMY0': 44,
#  'FDNC0': 45,
#  'FDRD1': 46,
#  'FDRW0': 47,
#  'FDTD0': 48,
#  'FDXW0': 49,
#  'FEAC0': 50,
#  'FEAR0': 51,
#  'FECD0': 52,
#  'FEDW0': 53,
#  'FEEH0': 54,
#  'FELC0': 55,
#  'FEME0': 56,
#  'FETB0': 57,
#  'FEXM0': 58,
#  'FGCS0': 59,
#  'FGDP0': 60,
#  'FGJD0': 61,
#  'FGMB0': 62,
# ...
